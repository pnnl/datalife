# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
index = ['Stage 0\n (staging)',
    'Stage 1\n (indiv)',
 'Stage 2\n (indiv_merge+sift)',
 'Stage 3\n (mut_olap+freq)',
 'Total']

# column = ['15nodes+NFS',
#  '15/bfs',
#  '10nodes+NFS',
#  '10nodes+NFS+shm',
#  '10nodes+NFS+ssd',
#  '10nodes+NFS+shm+staging',
#  '10nodes+NFS+ssd+staging',
#  '10/bfs',
#  '10/bfs+shm',
#  '10/bfs+ssd',
#  '10/bfs+shm+staging',
#  '10/bfs+ssd+staging',]
column = [
 '15/bfs',
 '10/bfs',
 '10/bfs+shm',
 '10/bfs+ssd',
 '10/bfs+shm+staging',
 '10/bfs+ssd+staging',]

# %%
# column == 15/bfs; index == Stage 1,2,3; the numbers need to update from the 1000genome_perf_number execution results
col_idx = 0 
bfs15 = [[column[col_idx], index[0], 0.0],
        [column[col_idx], index[1], 378.2],
             [column[col_idx], index[2], 569.4],
             [column[col_idx], index[3], 416.1],      
             [column[col_idx], index[4], 1363.7],      
             [column[col_idx], index[1], 328.4],
             [column[col_idx], index[2], 445.6],
             [column[col_idx], index[3], 339.7],     
             [column[col_idx], index[4], 1113.7],      
             [column[col_idx], index[1], 381.3],
             [column[col_idx], index[2], 404.2],
             [column[col_idx], index[3], 460.7],     
             [column[col_idx], index[4], 1246.2],      
             [column[col_idx], index[1], 294.4],
             [column[col_idx], index[2], 389.1],
             [column[col_idx], index[3], 451.7],     
             [column[col_idx], index[4], 1135.2],      
             [column[col_idx], index[1], 267.4],
             [column[col_idx], index[2], 465.5],
             [column[col_idx], index[3], 426.2],      
             [column[col_idx], index[4], 1159.1],      
            ]
# column == 10/bfs; index == Stage 1,2,3; the numbers need to update from the 1000genome_perf_number execution results
col_idx = 1 
bfs10 = [[column[col_idx], index[0], 0.0],
        [column[col_idx], index[1], 277.9],
            [column[col_idx], index[2], 378.3],
            [column[col_idx], index[3], 375.7],
            [column[col_idx], index[4], 1031.9],      
            [column[col_idx], index[1], 282.2],
            [column[col_idx], index[2], 312.8],
            [column[col_idx], index[3], 398.3],
            [column[col_idx], index[4], 993.3],      
            [column[col_idx], index[1], 372.3],
            [column[col_idx], index[2], 333.8],
            [column[col_idx], index[3], 401.1],
            [column[col_idx], index[4], 1107.2],      
            [column[col_idx], index[1], 394.9],
            [column[col_idx], index[2], 334.5],
            [column[col_idx], index[3], 369.2],
            [column[col_idx], index[4], 1098.6],      
            [column[col_idx], index[1], 331.2],
            [column[col_idx], index[2], 381.2],
            [column[col_idx], index[3], 354.3],
            [column[col_idx], index[4], 1066.7],      
            ]
# column == 10/bfs+shm; index == Stage 1,2,3; the numbers need to update from the 1000genome_perf_number execution results
col_idx = 2
bfs10shm = [[column[col_idx], index[0], 0.0],
        [column[col_idx], index[1], 340.5],
            [column[col_idx], index[2], 14.6],
            [column[col_idx], index[3], 105.8],
            [column[col_idx], index[4], 460.9],      
            [column[col_idx], index[1], 227.4],
            [column[col_idx], index[2], 11.0],
            [column[col_idx], index[3], 84.1],
            [column[col_idx], index[4], 322.5],      
            [column[col_idx], index[1], 222.8],
            [column[col_idx], index[2], 11.4],
            [column[col_idx], index[3], 89.7],
            [column[col_idx], index[4], 324.0],      
            [column[col_idx], index[1], 306.4],
            [column[col_idx], index[2], 22.3],
            [column[col_idx], index[3], 116.4],
            [column[col_idx], index[4], 445.1],      
            [column[col_idx], index[1], 243.8],
            [column[col_idx], index[2], 11.3],
            [column[col_idx], index[3], 112.9],
            [column[col_idx], index[4], 368.0],      
            ]
# column == 10/bfs+ssd; index == Stage 1,2,3; the numbers need to update from the 1000genome_perf_number execution results
col_idx = 3
bfs10ssd = [[column[col_idx], index[0], 0.0],
        [column[col_idx], index[1], 308.6],
            [column[col_idx], index[2], 13.6],
            [column[col_idx], index[3], 102.0],
            [column[col_idx], index[4], 424.1],      
            [column[col_idx], index[1], 525.0],
            [column[col_idx], index[2], 20.5],
            [column[col_idx], index[3], 108.8],
            [column[col_idx], index[4], 654.2],      
            [column[col_idx], index[1], 325.9],
            [column[col_idx], index[2], 15.4],
            [column[col_idx], index[3], 103.8],
            [column[col_idx], index[4], 445.1],      
            [column[col_idx], index[1], 506.9],
            [column[col_idx], index[2], 19.3],
            [column[col_idx], index[3], 104.7],
            [column[col_idx], index[4], 630.9],      
            [column[col_idx], index[1], 390.8],
            [column[col_idx], index[2], 15.7],
            [column[col_idx], index[3], 95.3],
            [column[col_idx], index[4], 501.9],      
            ]
# column == 10/bfs+shm+staging; index == Stage 1,2,3; the numbers need to update from the 1000genome_perf_number execution results
col_idx = 4
bfs10shm_sin = [[column[col_idx], index[0], 5.4],
            [column[col_idx], index[1], 8.6],
            [column[col_idx], index[2], 9.5],
            [column[col_idx], index[3], 58.9],
            [column[col_idx], index[4], 82.4],      
            [column[col_idx], index[0], 4.5],
            [column[col_idx], index[1], 7.5],
            [column[col_idx], index[2], 9.4],
            [column[col_idx], index[3], 59.7],
            [column[col_idx], index[4], 81.1],      
            [column[col_idx], index[0], 2.9],
            [column[col_idx], index[1], 8.4],
            [column[col_idx], index[2], 7.8],
            [column[col_idx], index[3], 60.1],
            [column[col_idx], index[4], 79.2],      
            [column[col_idx], index[0], 3.7],
            [column[col_idx], index[1], 7.6],
            [column[col_idx], index[2], 7.5],
            [column[col_idx], index[3], 60.0],
            [column[col_idx], index[4], 78.7],      
            [column[col_idx], index[0], 3.2],
            [column[col_idx], index[1], 7.3],
            [column[col_idx], index[2], 7.3],
            [column[col_idx], index[3], 57.0],
            [column[col_idx], index[4], 75.0],      
            ]
# column == 10/bfs+ssd+staging; index == Stage 1,2,3; the numbers need to update from the 1000genome_perf_number execution results
col_idx = 5
bfs10ssd_sin = [[column[col_idx], index[0], 3.4],
            [column[col_idx], index[1], 6.2],
            [column[col_idx], index[2], 13.0],
            [column[col_idx], index[3], 59.0],
            [column[col_idx], index[4], 81.6],      
            [column[col_idx], index[0], 5.7],
            [column[col_idx], index[1], 9.0],
            [column[col_idx], index[2], 12.3],
            [column[col_idx], index[3], 59.5],
            [column[col_idx], index[4], 86.5],      
            [column[col_idx], index[0], 3.2],
            [column[col_idx], index[1], 5.5],
            [column[col_idx], index[2], 10.9],
            [column[col_idx], index[3], 64.2],
            [column[col_idx], index[4], 83.7],      
            [column[col_idx], index[0], 4.1],
            [column[col_idx], index[1], 7.6],
            [column[col_idx], index[2], 16.8],
            [column[col_idx], index[3], 84.4],
            [column[col_idx], index[4], 113.0],      
            [column[col_idx], index[0], 3.9],
            [column[col_idx], index[1], 8.5],
            [column[col_idx], index[2], 13.1],
            [column[col_idx], index[3], 57.6],
            [column[col_idx], index[4], 83.1],      
            ]
data = bfs15 + bfs10 + bfs10shm + bfs10ssd + bfs10shm_sin + bfs10ssd_sin
# data

# %%
df__ = pd.DataFrame(data, columns=['configuration', 'stage', 'value'])

# %%
import itertools
# plt.figure(figsize=(12,4))
indexx = ['Stage 0\n (staging)',
    'Stage 1\n (indiv)',
 'Stage 2\n (indiv_merge+sift)',
 'Stage 3\n (mut_olap+freq)',
 'Total']
# ax = sns.barplot(data=df__[df__['stage']=='Total'], x='stage', y='value', hue='configuration', order=indexx)
hatches = ['/', '//', '+', '-', 'x', '\\', '*', 'o', 'O', '.', '..', '\\\\']
sns.set(font_scale=3.6)
sns.set_style(style='white') 
fig, axes = plt.subplots(1,5, figsize = (35,10))
fig.subplots_adjust(wspace=0.25)

for idx, ax in enumerate(axes.flat):
    axx=sns.barplot(data=df__[df__['stage']==indexx[idx]], x='stage', capsize=.012, y='value', hue='configuration', ax=ax)
    axx.set(xlabel=None)
    for hatch_pattern, these_bars in zip(hatches, axx.containers):
        for this_bar in these_bars:
            this_bar.set_hatch(hatch_pattern)
    # axx.set(xlabel=None)
    # axx.set_xlabel(indexx[idx], fontdict={'fontsize' : 16})
    if idx == 0:
        axx.set_ylabel('Seconds')
        axx.set(ylim=(0, 10))

    else:
        axx.set(ylabel=None)
    # ax.legend
    axx.get_legend().remove()

    # if idx == 1:
        # axx.set(ylim=(0, 600))
    
    if idx == 0:
        # ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
        # ax.legend(loc='upper left',borderaxespad=0)
        ax.legend(fontsize=31,borderaxespad=0)
# ax.set(ylabel='second')
# hatches = ['/', '//', '+', '-', 'x', '\\', '*', 'o', 'O', '.', '..', '\\\\']

# for hatch_pattern, these_bars in zip(hatches, ax.containers):
#     # Set a different hatch for each bar
#     for this_bar in these_bars:
#         this_bar.set_hatch(3 * hatch_pattern)
# ax.legend(loc='upper left')

# handles, labels = axes[0:5].get_legend_handles_labels()
# plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.savefig("1kgenome_performance.pdf",bbox_inches = "tight")
plt.show()

# %%
fig = ax.get_figure()
fig.savefig("1kgenome_comparison.pdf")
